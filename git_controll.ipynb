# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Kode/DFR/PML-TugBes2
# Out:
# /content/drive/MyDrive/Colab Notebooks/Kode/DFR/PML-TugBes2

# %%
# !git branch
# Out:
# * main

# %%
# !git status
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# Untracked files:
#   (use "git add <file>..." to include in what will be committed)
#
# 	fotoPeserta/
# 	fotoTest/
# 	git_controll.ipynb
#
# nothing added to commit but untracked files present (use "git add" to track)

# %%
# !git add --all

# %%
# !git commit -a -m "Updated All"
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@665eac1c8069.(none)')

# %%
# !git config --global user.email "onestringlab@gmail.com"

# %%
# !git config --global user.name "Onestringlab"

# %%
# !git remote remove origin

# %%
# !git remote add origin https://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@github.com/Onestringlab/PML-TugBes2.git

# %%
# !git push --set-upstream origin main
# Out:
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# Everything up-to-date
