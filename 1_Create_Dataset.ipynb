# %% [markdown]
# # PEMBUATAN KUMPULAN DATA

# %% [markdown]
# ## 1. Instalasi Deepface

# %%
# !pip install deepface

# %% [markdown]
# # 2. Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Kode/DFR/PML-TugBes2
# Out:
# /content/drive/MyDrive/Colab Notebooks/Kode/DFR/PML-TugBes2

# %% [markdown]
# # 3. Import Library

# %%
import os
import cv2
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity

from PIL import Image
from os import listdir
from deepface import DeepFace

# %% [markdown]
# # 4. Memproduksi, Menyimpan, Memuat dan Menampilkan data dari wajah.

# %% [markdown]
# ## Memproduksi data dari wajah dengan model Facenet

# %%
folder='AnggotaKelas/'
database = {}
models = ["VGG-Face", "Facenet", "Facenet512", "OpenFace", "DeepFace", "DeepID", "ArcFace", "Dlib"]
i = 6

for filename in listdir(folder):
    path = folder + filename
    number = DeepFace.represent(path, model_name=models[i], align=False,
                                enforce_detection = True)
    number = np.asarray(np.array(number))
    database[filename] = number
# Out:
# arcface_weights.h5  will be downloaded to  /root/.deepface/weights/arcface_weights.h5
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/arcface_weights.h5
# To: /root/.deepface/weights/arcface_weights.h5
# 100%|██████████| 137M/137M [00:09<00:00, 14.6MB/s]

# %% [markdown]
# ## Menyimpan data wajah ke dalam file .pkl

# %%
myfile = open("data.pkl", "wb")
pickle.dump(database, myfile)
myfile.close()

# %% [markdown]
# ## Memuat data wajah ke dalam file .pkl

# %%
myfile = open("data.pkl", "rb")
data = pickle.load(myfile)
myfile.close()

# %% [markdown]
# Menampilkan data wajah

# %%
data
# Out:
# {'Adiyasa Nurfalah.jpg': array([-7.60770887e-02,  1.44262359e-01,  1.32269654e-02, -2.73445696e-01,
#          1.67399962e-02,  1.46759935e-02,  5.96235693e-02, -1.75153792e-01,
#         -1.34397969e-02, -1.49373576e-01, -7.13461414e-02, -3.15190665e-02,
#         -4.84224617e-01, -2.07688008e-02,  1.93008125e-01, -5.80151789e-02,
#         -3.57335269e-01, -3.32799315e-01,  1.37532771e-01, -4.13809836e-01,
#         -2.86360890e-01,  2.83307694e-02,  2.81092823e-02, -2.63983816e-01,
#         -4.66825366e-02,  2.61747152e-01,  1.77105248e-01,  2.72931844e-01,
#          7.22358972e-02, -4.65380400e-01,  1.95367903e-01, -1.32310867e-01,
#          2.02500641e-01,  4.05628502e-01, -9.64136422e-02, -5.86082697e-01,
#         -3.11141640e-01, -3.37554693e-01, -1.69509351e-02,  2.61194617e-01,
#          2.64820188e-01,  7.45877177e-02,  8.77604261e-02, -2.64782935e-01,
#         -2.65339524e-01,  3.57908964e-01,  4.68837358e-02, -7.08886534e-02,
# ...
